# %% [markdown]
# ques 1  What is hypothesis testing in statistics?
#
# Hypothesis testing is a statistical method used to make inferences or draw conclusions about a population based on sample data. It helps determine whether there is enough evidence to support or reject a specific claim (hypothesis) about the population.

# %% [markdown]
# ques 2  What is the null hypothesis, and how does it differ from the alternative hypothesis?
#
# **Null Hypothesis (H₀):** The null hypothesis represents the default assumption or the statement that there is no effect, no difference, or no relationship in the population.
#
# It is the hypothesis that we assume to be true unless there is strong evidence against it.
#
# Typically, it suggests that any observed effect in the sample data is due to random chance.
#
# **Alternative Hypothesis (H₁ or Ha):** The alternative hypothesis represents the statement that there is an effect, a difference, or a relationship in the population.
#
# This is the hypothesis that researchers typically want to test for or prove. If there is enough evidence against the null hypothesis, the alternative hypothesis becomes more plausible.
#
# **difference:**
# 1. Purpose:
#
# The null hypothesis assumes no effect or no difference.
#
# The alternative hypothesis proposes that there is an effect or a difference.
#
# 2. What you’re testing:
#
# You are testing the null hypothesis to see if there is enough evidence to reject it in favor of the alternative hypothesis.
#
# 3. Default position:
#
# The null hypothesis is usually the starting point, and it represents the assumption that there is no change or effect.
#
# The alternative hypothesis is what you want to prove if the null is rejected.

# %% [markdown]
# ques 3  What is the significance level in hypothesis testing, and why is it important?
#
# The significance level (denoted as 𝛼) in hypothesis testing is a threshold that helps determine when to reject the null hypothesis. It represents the probability of making a Type I error, which occurs when you incorrectly reject the null hypothesis when it is actually true.
#
# **importance**:
#
# 1. The significance level sets the threshold for deciding how much evidence you need to reject the null hypothesis.
#
# 2. The significance level directly controls the probability of making a Type I error, which is rejecting a null hypothesis that is actually true.
#
# 3. The significance level helps establish a standard of comparison to evaluate the p-value. The p-value is the probability of obtaining the observed results (or more extreme ones) under the assumption that the null hypothesis is true. By comparing the p-value with 𝛼, you can determine whether to reject the null hypothesis.
#
# 4. The significance level is a way of balancing the risk of Type I error and Type II error, and it is essential for making objective decisions in hypothesis testing.

# %% [markdown]
# ques 4  What does a P-value represent in hypothesis testing?
#
# The p-value is the probability of obtaining a test statistic (or more extreme results) in your sample, assuming the null hypothesis is true.
#
# The p-value is a critical concept in hypothesis testing, and it helps you determine the strength of the evidence against the null hypothesis. Simply put, the p-value tells you how likely it is to observe the data you have (or something more extreme) assuming that the null hypothesis is true.

# %% [markdown]
# ques 5 How do you interpret the P-value in hypothesis testing?
#
# interpretation of p-value in hypothesis testing:
#
# P-value ≤ α	The observed data is unlikely under the null hypothesis. There is strong evidence to reject 𝐻0 , Reject the null hypothesis.
#
# P-value > α	The observed data is likely under the null hypothesis. There is insufficient evidence to reject 𝐻0 , Fail to reject the null hypothesis.

# %% [markdown]
# ques 6  What are Type 1 and Type 2 errors in hypothesis testing?
#
# Type I Error (False Positive):
#
# A Type I error occurs when you reject the null hypothesis even though it is actually true. In other words, you conclude that there is an effect or a difference when, in reality, there isn't.
#
# * It’s often referred to as a false positive, because you mistakenly detect an effect or relationship that doesn’t actually exist.
#
# Type II Error (False Negative):
#
# A Type II error occurs when you fail to reject the null hypothesis even though it is actually false. In other words, you conclude that there is no effect or difference when, in fact, there is one.
#
# * It’s often referred to as a false negative, because you fail to detect a real effect or relationship.

# %% [markdown]
# ques 7  What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#
#
# One-Tailed Test:
#
# A one-tailed test is used when you are testing for the possibility of an effect in only one direction. This type of test is used when you have a specific hypothesis about the direction of the effect — whether it's greater than or less than a certain value.
#
# Two-Tailed Test:
#
# A two-tailed test is used when you are testing for the possibility of an effect in either direction. In other words, you are checking if the sample data is either significantly greater than or less than the population parameter.

# %% [markdown]
# ques 8 What is the Z-test, and when is it used in hypothesis testing?
#
# The Z-test is a statistical test used in hypothesis testing to determine whether there is a significant difference between the sample mean and the population mean (or between two sample means) under certain conditions.
#
# The Z-test is typically used when:
#
# **The population variance (or standard deviation) is known:** If you know the population standard deviation (σ), you can use the Z-test to assess whether your sample mean significantly differs from the population mean.
#
# **Sample size is large:** If the sample size is large enough **(usually n≥30)**, the Central Limit Theorem ensures that the sampling distribution of the sample mean is approximately normal, even if the population distribution is not normal. This allows you to use the Z-test.
#
# **The sample is from a normally distributed population:** If the population from which the sample is drawn is normally distributed, the Z-test can be used to test hypotheses about the population mean.
#
# **Testing for a single mean or comparing two means:** The Z-test can be used for testing hypotheses about a single sample mean or for comparing the means of two independent samples.

# %% [markdown]
# ques 9  How do you calculate the Z-score, and what does it represent in hypothesis testing?
#
# The Z-score is a statistical measure that describes how many standard deviations a data point (or sample statistic) is away from the mean of a distribution. In the context of hypothesis testing, the Z-score helps determine whether the observed data is statistically significant compared to what we would expect under the null hypothesis.
#
# Formula for Z-Score:𝑍=𝑋−𝜇 / 𝜎
# ​
#
# Where:
#
# X = the observed value (e.g., sample mean, individual data point, or observed statistic)
#
# μ = the population mean (or the mean under the null hypothesis)
#
# σ = the population standard deviation
#
# The Z-score tells you how many standard deviations the sample statistic is from the population mean under the null hypothesis. In other words, it helps you understand how unusual or extreme your observed value is, given the null hypothesis.

# %% [markdown]
# ques 10 What is the T-distribution, and when should it be used instead of the normal distribution?
#
# he T-distribution (also called the Student's t-distribution) is a probability distribution that is very similar to the normal distribution but has heavier tails. This means that the t-distribution assigns more probability to extreme values than the normal distribution does.
#
# When to Use the T-Distribution:
#
# 1. Small Sample Size: When your sample size is small (typically n<30), the sample mean may not be an accurate estimate of the population mean, and the sample standard deviation may not accurately reflect the population standard deviation.
#
#
# 2. Unknown Population Standard Deviation: If the population standard deviation (σ) is unknown, you must estimate it from the sample. This introduces extra variability, and the T-distribution is used to account for this added uncertainty. In contrast, the Z-test assumes that you know the population standard deviation.
#
# 3. When Conducting a T-Test: A T-test is typically used in hypothesis testing for small sample sizes or when the population standard deviation is unknown.
#
#  The three main types of t-tests are:
#
#  One-sample t-test: Compares the sample mean to a known population mean.
#
#  Independent two-sample t-test: Compares the means of two independent samples.
#
#  Paired sample t-test: Compares the means of two related groups (e.g., before and after treatment for the same group of individuals).
#
# 4. Increased Uncertainty with Small Samples:
#
# Small samples are more prone to variability, and the T-distribution helps correct for the uncertainty by providing more conservative (wider) confidence intervals and larger critical values compared to the normal distribution.

# %% [markdown]
# ques 11  What is the difference between a Z-test and a T-test?
#
# **Differences:**
#
#  1. **Distribution:**
#
# Z-test: Uses the normal distribution (also called the Z-distribution) when the population standard deviation is known and the sample size is large (typically n > 30).
#
# T-test: Uses the t-distribution, which is similar to the normal distribution but has heavier tails. The t-distribution is used when the sample size is small (typically n < 30) or when the population standard deviation is unknown.
#
# 2. **Population Standard Deviation:**
#
# Z-test: Assumes that the population standard deviation (σ) is known.
#
# T-test: Assumes that the population standard deviation is unknown and instead uses the sample's standard deviation (s) as an estimate.
#
# 3.  **When to Use Each:**
#
# Z-test: When the population standard deviation is known. When the sample size is large.
#
# T-test: When the population standard deviation is unknown. when the sample size is small.

# %% [markdown]
# ques 12 What is the T-test, and how is it used in hypothesis testing ?
#
# The T-test is a statistical test used to compare the means of two groups and determine whether the difference between them is statistically significant. It's widely used in hypothesis testing when you don't know the population standard deviation or when your sample size is small (typically less than 30).
#
# use of T-test in hypothesis testing:
#
# The T-test is an essential tool in hypothesis testing used to evaluate whether there is a statistically significant difference between the means of two groups or a sample mean and a population mean. Its main advantages are:
#
# 1. Handling small sample sizes.
# 2. Assessing differences in means when the population standard deviation is unknown.
# 3. Determining statistical significance in experimental and observational studies.
#
# The type of T-test you use (one-sample, two-sample, or paired) depends on your research question, the data structure, and whether the groups are independent or related. By following a systematic approach, you can use the T-test to draw conclusions about the population based on your sample data.

# %% [markdown]
# ques 13 What is the relationship between Z-test and T-test in hypothesis testing ?
#
# The relationship between Z-test and T-test in hypothesis testing :
#
# * The Z-test and T-test are very similar, both being used for hypothesis testing regarding means.
#
# * The key difference is in the distribution: Z-test uses the normal distribution (Z-distribution), while the T-test uses the t-distribution.
#
# * Z-test is used when the population standard deviation is known, and the sample size is large.
#
# * T-test is used when the population standard deviation is unknown, or the sample size is small.
#
# * As the sample size increases, the T-test and Z-test become nearly identical in their results.

# %% [markdown]
# ques 14  What is a confidence interval, and how is it used to interpret statistical results ?
#
# A confidence interval (CI) is a statistical tool used to estimate the range within which a population parameter (such as a mean or proportion) is likely to fall, based on sample data. It gives a range of plausible values for the parameter, accompanied by a level of confidence (usually 95% or 99%) that the true value lies within that range.
#
# How is a Confidence Interval Used to Interpret Statistical Results:
#
# 1. Precision of the Estimate:
# The width of the confidence interval indicates the precision of the estimate.
# A narrow confidence interval suggests that the sample estimate is precise, while a wide interval suggests that there's more uncertainty about the true population parameter.
#
# 2. Statistical Significance:
# Confidence intervals can be used to assess whether a value (like a hypothesized population mean or difference) is statistically significant.
# If the interval does not contain the null value (e.g., zero for a difference in means or one for a ratio of means), the result is considered statistically significant at the chosen confidence level.
#
# 3. Estimating Population Parameters:
#
# Confidence intervals give you a range of values that are likely to contain the true population parameter.
#
# 4. Making Decisions:
#
# Confidence intervals provide a practical way to make decisions. For instance:
# If you are estimating the average height of a group of people, and the confidence interval for the mean height is wide, it suggests that your estimate is imprecise and additional data might be needed.

# %% [markdown]
# ques 15 What is the margin of error, and how does it affect the confidence interval ?
#
# The margin of error (MoE) is a measure of the uncertainty or potential error in a statistical estimate, such as a sample mean or proportion. It represents the range of values above and below the sample estimate that is likely to contain the true population parameter with a certain level of confidence.
#
# how does it affect the confidence interval:
#
# * A larger margin of error results in a wider confidence interval, indicating more uncertainty about the true population parameter.
#
# * The confidence level (e.g., 95% or 99%) determines how certain you are that the true parameter lies within the interval, and higher confidence levels lead to wider intervals.
#
# * The sample size and standard deviation also affect the margin of error: a larger sample size or smaller standard deviation reduces the margin of error.

# %% [markdown]
# ques 16 How is Bayes' Theorem used in statistics, and what is its significance?
#
# Bayes' Theorem is a fundamental concept in statistics and probability theory that allows us to update our beliefs (probabilities) about a hypothesis based on new evidence or data. It's particularly useful in situations where we have incomplete or uncertain information and want to refine our predictions or understand the likelihood of an event given new data.
#
# Significance of Bayes' Theorem in Statistics:
#
# 1. **Dynamic Updating of Beliefs:** Bayes' Theorem allows you to continually update your beliefs or understanding as new evidence becomes available. This is especially useful in real-world situations where information is constantly changing, and you need to adjust your predictions accordingly.
#
# 2. **Decision Making**: In many fields such as medicine, finance, and machine learning, Bayes' Theorem provides a structured approach to making decisions under uncertainty. By taking prior knowledge (prior probability) and new data (likelihood), you can calculate the most probable outcomes and make more informed decisions.
#
# 3. **Incorporating Prior Knowledge**: Bayesian inference allows the integration of prior knowledge into the analysis. For example, if you have expert knowledge or historical data that suggests a certain outcome is more likely, you can incorporate that into your model rather than relying purely on new data.
#
# 4. **Dealing with Uncertainty:** Bayes' Theorem is especially valuable in uncertain situations, where data may be noisy or incomplete. By incorporating uncertainty and continuously updating predictions, Bayesian methods offer a more flexible and nuanced approach to modeling than traditional frequentist methods.
#
# 5. **Machine Learning and AI:** Bayesian methods are used extensively in machine learning and artificial intelligence for tasks such as classification, anomaly detection, and predictive modeling. Naive Bayes classifiers, for instance, are simple probabilistic classifiers based on Bayes' Theorem, widely used in text classification and spam filtering.

# %% [markdown]
# ques 17 What is the Chi-square distribution, and when is it used?
#
# The Chi-square distribution (denoted as 𝜒2) is a probability distribution that is widely used in statistical inference. It is a special case of the gamma distribution and plays a key role in hypothesis testing and confidence interval estimation, particularly in tests involving categorical data and variance.
#
# Key uses:
#
# * Goodness-of-Fit Test: Checking if observed data matches an expected distribution.
#
# * Test for Independence: Examining the relationship between two categorical variables.
#
# * Test for Variance: Testing if a sample variance matches a hypothesized population variance

# %% [markdown]
# ques 18 What is the Chi-square goodness of fit test, and how is it applied ?
#
# The Chi-square goodness of fit test is a statistical test used to determine whether the observed frequencies of a categorical variable match the expected frequencies based on a given hypothesis or distribution.
#
# steps to apply Chi-square goodness of fit test :
#
# 1. Define hypotheses (H₀ and H₁).
#
# 2. Collect observed data (frequencies of categories).
#
# 3. Calculate expected frequencies (based on theory or hypothesis).
#
# 4. Calculate the Chi-square statistic using the formula.
#
# 5. Determine the degrees of freedom (df=k−1).
#
# 6. Find the critical value from the Chi-square distribution table, or calculate the p-value.
#
# 7. Make the decision (reject or fail to reject the null hypothesis).
#
# 8. Interpret the results (does the data fit the expected distribution?).

# %% [markdown]
# ques 19 What is the F-distribution, and when is it used in hypothesis testing ?
#
# The F-distribution is a continuous probability distribution that is used primarily in hypothesis testing and in the analysis of variance. It plays a crucial role in ANOVA (Analysis of Variance), regression analysis, and tests of variances.
#
# Uses of the F-distribution in Hypothesis Testing:
#
# 1. Analysis of Variance (ANOVA):
#
# ANOVA tests the hypothesis that the means of several groups are equal by comparing the variances within groups and between groups.
# In one-way or two-way ANOVA, the F-statistic is calculated as the ratio of the variance between the groups to the variance within the groups.
#
# 2. F-test for Equality of Variances:
#
# The F-distribution is used in F-tests to compare the variances of two independent samples (e.g., testing if two population variances are equal).
# The hypothesis test involves calculating the ratio of the sample variances, and comparing this ratio to the critical value from the F-distribution.
#
# 3. Regression Analysis:
#
# In multiple regression or model comparison, the F-statistic is used to test the overall significance of the model.
# The F-test in regression evaluates whether the model with predictors explains more variance in the dependent variable than a model with no predictors (i.e., only the intercept).
#
# 4. Testing Hypotheses in Factorial Designs:
#
# In experiments with multiple factors (e.g., in a two-way ANOVA), the F-distribution is used to test the significance of the interaction between the factors and the main effects.
#
#
#
#
#
#
#
#
# ​

# %% [markdown]
# ques 20  What is an ANOVA test, and what are its assumptions?
#
# ANOVA is a statistical method used to compare means across three or more groups to determine if at least one group mean is significantly different from the others. It helps test the hypothesis that the means of different groups are equal.
#
# **Assumptions in ANOVA:**
#
# * Independence of observations (the data from one group should not affect the data from another group).
#
# * Normality (the data in each group should follow a normal distribution).
#
# * Homogeneity of variances (the variances within each group should be approximately equal).

# %% [markdown]
# ques 21  What are the different types of ANOVA tests?
#
# **Types of ANOVA tests :**
#
# 1. One-Way ANOVA: One factor, comparing means across multiple groups.
#
# 2. Two-Way ANOVA: Two factors, including the possibility of an interaction effect.
#
# 3. Repeated Measures ANOVA: Same subjects measured at different times or under different conditions.
#
# 4. MANOVA: Multiple dependent variables tested simultaneously.
#
# 5. Factorial ANOVA: Multiple factors, with main effects and interactions.
#
# 6. Mixed-Design ANOVA: Combines repeated measures and factorial designs.

# %% [markdown]
# ques 22 What is the F-test, and how does it relate to hypothesis testing?
#
# The F-test is a statistical test used to compare the variances of two or more groups to determine if they are significantly different. It is based on the F-distribution, which is the ratio of two scaled chi-square distributions, and is primarily used in the context of variance analysis.
#
# The F-test is most commonly used in Analysis of Variance (ANOVA) and regression analysis. It helps in testing hypotheses about the variances and the relationships between variables.
#
# **F-test in Hypothesis Testing:**
#
# 1. Purpose: The F-test is used to compare variances or assess the significance of a regression model. It helps in determining whether the observed variances are significantly different or whether a regression model is significant.
#
# 2. In ANOVA: It tests whether there are significant differences between group means by comparing the variance between groups to the variance within groups.
#
# 3. In Regression: It tests whether the overall regression model explains a significant amount of the variance in the dependent variable, based on the ratio of explained variance to residual variance.
#
# 4. F-statistic Calculation: The F-statistic is the ratio of variances (or mean squares). A larger F-statistic indicates a more significant difference between groups or a more useful regression model.
#
# 5. Decision Rule: If the calculated F-statistic exceeds the critical F-value from the F-distribution table, we reject the null hypothesis, indicating significant differences or a significant model.

# %% [markdown]
# # **pratical**

# %%
#ques 1  Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.

import numpy as np
import scipy.stats as stats

def z_test(sample_mean, population_mean, population_std, sample_size, alpha=0.05):
    z_stat = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    p_value = 2 * (1 - stats.norm.cdf(abs(z_stat)))
    print(f"Z-statistic: {z_stat}")
    print(f"P-value: {p_value}")
    if p_value < alpha:
        print(f"Reject the null hypothesis at the {alpha * 100}% significance level.")
    else:
        print(f"Fail to reject the null hypothesis at the {alpha * 100}% significance level.")
sample_mean = 105
population_mean = 100
population_std = 15
sample_size = 50

z_test(sample_mean, population_mean, population_std, sample_size)
# Out:
# Z-statistic: 2.3570226039551585
# P-value: 0.018422125454099048
# Reject the null hypothesis at the 5.0% significance level.

# %%
#ques 2  Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python


import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
np.random.seed(0)
population_mean = 100
population_std = 15
sample_size = 30
sample_data = np.random.normal(loc=population_mean, scale=population_std, size=sample_size)
sample_mean = np.mean(sample_data)
sample_std = np.std(sample_data, ddof=1)


t_stat = (sample_mean - population_mean) / (sample_std / np.sqrt(sample_size))
df = sample_size - 1
p_value = 2 * (1 - stats.t.cdf(np.abs(t_stat), df))
alpha = 0.05
print(f"Sample Mean: {sample_mean}")
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the sample mean and population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the sample mean and population mean.")
x = np.linspace(population_mean - 4 * population_std, population_mean + 4 * population_std, 1000)
y = stats.norm.pdf(x, population_mean, population_std)

plt.plot(x, y, label="Population Distribution")
plt.hist(sample_data, bins=10, alpha=0.7, density=True, label="Sample Data")
plt.axvline(sample_mean, color='r', linestyle='dashed', label=f"Sample Mean: {sample_mean:.2f}")
plt.legend()
plt.title("Population vs Sample Distribution")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()
# Out:
# Sample Mean: 106.64284670894763
# T-statistic: 2.204455162760578
# P-value: 0.03558027071269465
# Reject the null hypothesis: There is a significant difference between the sample mean and population mean.

# %%
#ques 3  Implement a one-sample Z-test using Python to compare the sample mean with the population mean.

def z_test_one_sample(sample_data, population_mean, population_std, alpha=0.05):

    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)
    z_stat = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    p_value = 2 * (1 - stats.norm.cdf(abs(z_stat)))
    print(f"Sample Mean: {sample_mean}")
    print(f"Z-statistic: {z_stat}")
    print(f"P-value: {p_value}")
    if p_value < alpha:
        print(f"Reject the null hypothesis: There is a significant difference between the sample mean and population mean.")
    else:
        print(f"Fail to reject the null hypothesis: No significant difference between the sample mean and population mean.")
np.random.seed(0)
population_mean = 100
population_std = 15
sample_data = np.random.normal(loc=population_mean, scale=population_std, size=30)
z_test_one_sample(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 106.64284670894763
# Z-statistic: 2.425624659026381
# P-value: 0.015282066343743406
# Reject the null hypothesis: There is a significant difference between the sample mean and population mean.

# %%
#ques 4 Perform a two-tailed Z-test using Python and visualize the decision region on a plot.

def z_test_two_tailed(sample_data, population_mean, population_std, alpha=0.05):
    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)
    z_stat = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    critical_value = stats.norm.ppf(1 - alpha/2)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_stat)))
    print(f"Sample Mean: {sample_mean}")
    print(f"Z-statistic: {z_stat}")
    print(f"P-value: {p_value}")
    if p_value < alpha:
        print(f"Reject the null hypothesis: There is a significant difference between the sample mean and population mean.")
    else:
        print(f"Fail to reject the null hypothesis: No significant difference between the sample mean and population mean.")
    visualize_decision_region(z_stat, critical_value, alpha)
def visualize_decision_region(z_stat, critical_value, alpha):
    x = np.linspace(-4, 4, 1000)
    y = stats.norm.pdf(x, 0, 1)
    plt.plot(x, y, label='Standard Normal Distribution')
    plt.fill_between(x, y, where=(x <= -critical_value), color='red', alpha=0.5, label='Rejection Region (left)')
    plt.fill_between(x, y, where=(x >= critical_value), color='red', alpha=0.5, label='Rejection Region (right)')
    plt.axvline(x=critical_value, color='blue', linestyle='dashed', label=f'Critical Z-value = {critical_value:.2f}')
    plt.axvline(x=-critical_value, color='blue', linestyle='dashed')
    plt.axvline(x=z_stat, color='green', linestyle='solid', label=f'Z-statistic = {z_stat:.2f}')

    plt.title("Two-Tailed Z-Test: Decision Region")
    plt.xlabel("Z-values")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.show()
np.random.seed(0)
population_mean = 100
population_std = 15
sample_data = np.random.normal(loc=population_mean, scale=population_std, size=30)
z_test_two_tailed(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 106.64284670894763
# Z-statistic: 2.425624659026381
# P-value: 0.015282066343743406
# Reject the null hypothesis: There is a significant difference between the sample mean and population mean.

# %%
#ques 5  Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.

def visualize_type_errors(population_mean, sample_mean, population_std, sample_size, alpha=0.05):
    n = sample_size
    sigma = population_std
    z_critical = stats.norm.ppf(1 - alpha/2)
    z_stat = (sample_mean - population_mean) / (sigma / np.sqrt(n))
    x = np.linspace(population_mean - 5*sigma, population_mean + 5*sigma, 1000)
    y = stats.norm.pdf(x, population_mean, sigma / np.sqrt(n))

    plt.plot(x, y, label="Sampling Distribution under H₀", color='blue')


    plt.fill_between(x, y, where=(x <= population_mean - z_critical * (sigma / np.sqrt(n))), color='red', alpha=0.3, label="Type I Error (α) Region (Left)")
    plt.fill_between(x, y, where=(x >= population_mean + z_critical * (sigma / np.sqrt(n))), color='red', alpha=0.3, label="Type I Error (α) Region (Right)")


    alternative_mean = sample_mean
    beta_x = np.linspace(alternative_mean - 5*sigma, alternative_mean + 5*sigma, 1000)
    beta_y = stats.norm.pdf(beta_x, alternative_mean, sigma / np.sqrt(n))

    plt.fill_between(beta_x, beta_y, where=(beta_x > population_mean - z_critical * (sigma / np.sqrt(n))) & (beta_x < population_mean + z_critical * (sigma / np.sqrt(n))), color='green', alpha=0.3, label="Type II Error (β) Region")


    plt.axvline(population_mean - z_critical * (sigma / np.sqrt(n)), color='black', linestyle='dashed', label="Critical Value - Left")
    plt.axvline(population_mean + z_critical * (sigma / np.sqrt(n)), color='black', linestyle='dashed', label="Critical Value - Right")


    plt.axvline(sample_mean, color='orange', linestyle='solid', label=f"Sample Mean: {sample_mean}")
    plt.axvline(population_mean, color='green', linestyle='solid', label=f"Population Mean: {population_mean}")

    plt.title("Type I and Type II Errors in Hypothesis Testing")
    plt.xlabel("Value")
    plt.ylabel("Density")
    plt.legend(loc="upper left")
    plt.show()


population_mean = 100
sample_mean = 105
population_std = 15
sample_size = 30
alpha = 0.05
visualize_type_errors(population_mean, sample_mean, population_std, sample_size, alpha)

# %%
#ques 6  Write a Python program to perform an independent T-test and interpret the results.

def independent_t_test(group1, group2, alpha=0.05):
    t_stat, p_value = stats.ttest_ind(group1, group2)
    print(f"T-statistic: {t_stat}")
    print(f"P-value: {p_value}")
    if p_value < alpha:
        print(f"Reject the null hypothesis: There is a significant difference between the two groups.")
    else:
        print(f"Fail to reject the null hypothesis: No significant difference between the two groups.")
np.random.seed(0)
group1 = np.random.normal(loc=50, scale=10, size=30)
group2 = np.random.normal(loc=55, scale=12, size=30)
independent_t_test(group1, group2, alpha=0.05)
# Out:
# T-statistic: 1.023255899922574
# P-value: 0.3104359181654011
# Fail to reject the null hypothesis: No significant difference between the two groups.

# %%
#ques 7  Perform a paired sample T-test using Python and visualize the comparison result

def paired_t_test(before, after, alpha=0.05):
    differences = after - before
    t_stat, p_value = stats.ttest_rel(before, after)
    print(f"T-statistic: {t_stat}")
    print(f"P-value: {p_value}")
    if p_value < alpha:
        print(f"Reject the null hypothesis: There is a significant difference between the two groups.")
    else:
        print(f"Fail to reject the null hypothesis: No significant difference between the two groups.")
    visualize_comparison(before, after, differences)
def visualize_comparison(before, after, differences):
    plt.figure(figsize=(10, 6))
    plt.scatter(range(len(before)), before, color='blue', label='Before')
    plt.scatter(range(len(after)), after, color='red', label='After')
    for i in range(len(before)):
        plt.plot([i, i], [before[i], after[i]], color='gray', linestyle='dashed')

    plt.xlabel("Subjects (or Pairs)")
    plt.ylabel("Values")
    plt.title("Paired Sample Comparison: Before and After")
    plt.legend()
    plt.show()
np.random.seed(0)
before = np.random.normal(loc=50, scale=10, size=30)
after = before + np.random.normal(loc=5, scale=3, size=30)
paired_t_test(before, after, alpha=0.05)
# Out:
# T-statistic: -8.25050870844368
# P-value: 4.268281116176562e-09
# Reject the null hypothesis: There is a significant difference between the two groups.

# %%
#ques 8 Simulate data and perform both Z-test and T-test, then compare the results using Python

def z_test(sample, population_mean, population_std, alpha=0.05):
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    z_stat = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    p_value = 2 * (1 - stats.norm.cdf(abs(z_stat)))

    print("Z-test Results:")
    print(f"Z-statistic: {z_stat:.4f}")
    print(f"P-value: {p_value:.4f}")
    if p_value < alpha:
        print("Reject the null hypothesis: There is a significant difference.")
    else:
        print("Fail to reject the null hypothesis: No significant difference.")
    print()
def t_test(sample, population_mean, alpha=0.05):
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    sample_std = np.std(sample, ddof=1)
    t_stat, p_value = stats.ttest_1samp(sample, population_mean)

    print("T-test Results:")
    print(f"T-statistic: {t_stat:.4f}")
    print(f"P-value: {p_value:.4f}")
    if p_value < alpha:
        print("Reject the null hypothesis: There is a significant difference.")
    else:
        print("Fail to reject the null hypothesis: No significant difference.")
    print()
np.random.seed(0)
population_mean = 50
population_std = 10

sample_size = 30
sample = np.random.normal(loc=52, scale=10, size=sample_size)  # Sample mean = 52

z_test(sample, population_mean, population_std, alpha=0.05)
t_test(sample, population_mean, alpha=0.05)

plt.figure(figsize=(8, 6))
x = np.linspace(min(sample) - 5, max(sample) + 5, 1000)
plt.hist(sample, bins=10, density=True, alpha=0.6, color='g', label='Sample Data')

plt.axvline(population_mean, color='b', linestyle='dashed', linewidth=2, label=f'Population Mean: {population_mean}')
plt.title("Histogram of Sample Data with Population Mean")
plt.xlabel("Value")
plt.ylabel("Density")
plt.legend()
plt.show()
# Out:
# Z-test Results:
# Z-statistic: 3.5211
# P-value: 0.0004
# Reject the null hypothesis: There is a significant difference.
#
# T-test Results:
# T-statistic: 3.2000
# P-value: 0.0033
# Reject the null hypothesis: There is a significant difference.

# %%
#ques 9  Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

def confidence_interval(sample, confidence_level=0.95, population_std=None):
    """
    Calculate the confidence interval for a sample mean.

    Parameters:
        sample (array-like): The sample data.
        confidence_level (float): The confidence level (default is 95%).
        population_std (float): The population standard deviation (if known).
                               If None, sample standard deviation will be used.

    Returns:
        tuple: Lower and upper bounds of the confidence interval.
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    if population_std is not None:
        std_dev = population_std
        critical_value = stats.norm.ppf(1 - (1 - confidence_level) / 2)
    else:
        std_dev = np.std(sample, ddof=1)
        critical_value = stats.t.ppf(1 - (1 - confidence_level) / 2, df=sample_size - 1)  # T-value for the confidence level
    margin_of_error = critical_value * (std_dev / np.sqrt(sample_size))
    ci_lower = sample_mean - margin_of_error
    ci_upper = sample_mean + margin_of_error

    return (ci_lower, ci_upper)
np.random.seed(0)
sample_data = np.random.normal(loc=50, scale=10, size=30)
ci = confidence_interval(sample_data, confidence_level=0.95)
print(f"Confidence Interval: {ci}")
# Out:
# Confidence Interval: (np.float64(50.3198706400115), np.float64(58.53725830525198))

# %%
#ques 10 Write a Python program to calculate the margin of error for a given confidence level using sample data


def margin_of_error(sample, confidence_level=0.95, population_std=None):
    """
    Calculate the margin of error for a given sample and confidence level.

    Parameters:
        sample (array-like): The sample data.
        confidence_level (float): The confidence level (default is 95%).
        population_std (float): The population standard deviation (if known).
                               If None, sample standard deviation will be used.

    Returns:
        float: The margin of error.
    """
    sample_size = len(sample)
    sample_mean = np.mean(sample)
    if population_std is not None:
        std_dev = population_std
        critical_value = stats.norm.ppf(1 - (1 - confidence_level) / 2)
    else:
        std_dev = np.std(sample, ddof=1)
        critical_value = stats.t.ppf(1 - (1 - confidence_level) / 2, df=sample_size - 1)
    margin_of_error = critical_value * (std_dev / np.sqrt(sample_size))

    return margin_of_error
np.random.seed(0)
sample_data = np.random.normal(loc=50, scale=10, size=30)

moe = margin_of_error(sample_data, confidence_level=0.95)
print(f"Margin of Error: {moe:.4f}")
# Out:
# Margin of Error: 4.1087

# %%
# ques 11 Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process

P_H = 0.01
P_E_given_H = 0.9
P_E_given_not_H = 0.05

P_not_H = 1 - P_H

P_E = P_E_given_H * P_H + P_E_given_not_H * P_not_H

P_H_given_E = (P_E_given_H * P_H) / P_E
print(f"The probability that the person has the disease given a positive test result (P(H|E)) is: {P_H_given_E:.4f}")
# Out:
# The probability that the person has the disease given a positive test result (P(H|E)) is: 0.1538

# %%
#ques 12  Perform a Chi-square test for independence between two categorical variables in Python.
import pandas as pd
from scipy.stats import chi2_contingency
data = {
    'High School': [30, 10],
    'College': [20, 40],
}
df = pd.DataFrame(data, index=['Cat', 'Dog'])
print("Contingency Table (Observed Data):\n", df)
chi2_stat, p_value, dof, expected = chi2_contingency(df)
print("\nChi-Square Statistic:", chi2_stat)
print("P-Value:", p_value)
print("Degrees of Freedom:", dof)
print("\nExpected Frequencies:\n", expected)

alpha = 0.05

if p_value < alpha:
    print("\nReject the null hypothesis: There is a significant association between education level and pet preference.")
else:
    print("\nFail to reject the null hypothesis: There is no significant association between education level and pet preference.")
# Out:
# Contingency Table (Observed Data):
#       High School  College
# Cat           30       20
# Dog           10       40
#
# Chi-Square Statistic: 15.041666666666668
# P-Value: 0.00010516355403363114
# Degrees of Freedom: 1
#
# Expected Frequencies:
#  [[20. 30.]
#  [20. 30.]]
#
# Reject the null hypothesis: There is a significant association between education level and pet preference.

# %%
#ques 13  Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data

observed_data = np.array([[30, 20, 10],
                          [10, 40, 50]])
row_totals = observed_data.sum(axis=1)
col_totals = observed_data.sum(axis=0)
grand_total = observed_data.sum()

expected_frequencies = np.outer(row_totals, col_totals) / grand_total

print("Observed Frequencies:\n", observed_data)
print("\nRow Totals:", row_totals)
print("Column Totals:", col_totals)
print("Grand Total:", grand_total)

print("\nExpected Frequencies (for each cell in the contingency table):\n", expected_frequencies)
# Out:
# Observed Frequencies:
#  [[30 20 10]
#  [10 40 50]]
#
# Row Totals: [ 60 100]
# Column Totals: [40 60 60]
# Grand Total: 160
#
# Expected Frequencies (for each cell in the contingency table):
#  [[15.  22.5 22.5]
#  [25.  37.5 37.5]]

# %%
#ques 14 Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.

import numpy as np
from scipy.stats import chisquare
observed_data = np.array([12, 9, 10, 8, 11, 10])

expected_data = np.array([10, 10, 10, 10, 10, 10])

chi2_stat, p_value = chisquare(observed_data, expected_data)

print(f"Chi-Square Statistic: {chi2_stat}")
print(f"P-Value: {p_value}")
alpha = 0.05

if p_value < alpha:
    print("\nReject the null hypothesis: The die is not fair.")
else:
    print("\nFail to reject the null hypothesis: There is no evidence that the die is unfair.")
# Out:
# Chi-Square Statistic: 1.0
# P-Value: 0.9625657732472964
#
# Fail to reject the null hypothesis: There is no evidence that the die is unfair.

# %%
#ques 15 Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics

import matplotlib.pyplot as plt
from scipy.stats import chi2
def plot_chi_square_distribution(degrees_of_freedom):
    x = np.linspace(0, 20, 1000)

    plt.figure(figsize=(10, 6))

    for df in degrees_of_freedom:
        plt.plot(x, chi2.pdf(x, df), label=f'df = {df}')
    plt.title('Chi-Square Distribution for Different Degrees of Freedom', fontsize=16)
    plt.xlabel('Chi-Square Value', fontsize=12)
    plt.ylabel('Probability Density', fontsize=12)
    plt.legend(title="Degrees of Freedom")
    plt.grid(True)
    plt.show()
degrees_of_freedom = [1, 2, 5, 10, 20]
plot_chi_square_distribution(degrees_of_freedom)

# %%
#ques 16  Implement an F-test using Python to compare the variances of two random samples


import numpy as np
from scipy.stats import f
def f_test(sample1, sample2):
    var1 = np.var(sample1, ddof=1)
    var2 = np.var(sample2, ddof=1)
    f_stat = var1 / var2 if var1 >= var2 else var2 / var1
    df1 = len(sample1) - 1
    df2 = len(sample2) - 1
    p_value = 2 * min(f.cdf(f_stat, df1, df2), 1 - f.cdf(f_stat, df1, df2))  # Two-tailed test

    return f_stat, p_value, df1, df2
np.random.seed(42)
sample1 = np.random.normal(loc=10, scale=5, size=100)
sample2 = np.random.normal(loc=10, scale=7, size=100)
f_stat, p_value, df1, df2 = f_test(sample1, sample2)
print(f"F-statistic: {f_stat}")
print(f"P-value: {p_value}")
print(f"Degrees of freedom for Sample 1: {df1}")
print(f"Degrees of freedom for Sample 2: {df2}")
alpha = 0.05

if p_value < alpha:
    print("\nReject the null hypothesis: The variances are significantly different.")
else:
    print("\nFail to reject the null hypothesis: There is no significant difference in variances.")
# Out:
# F-statistic: 2.161317511716075
# P-value: 0.00015751719146761545
# Degrees of freedom for Sample 1: 99
# Degrees of freedom for Sample 2: 99
#
# Reject the null hypothesis: The variances are significantly different.

# %%
#ques17  Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results.

group1 = [90, 85, 88, 92, 87]
group2 = [78, 80, 84, 76, 79]
group3 = [85, 89, 87, 90, 91]
f_statistic, p_value = stats.f_oneway(group1, group2, group3)
print(f"F-statistic: {f_statistic:.4f}")
print(f"P-value: {p_value:.4f}")
alpha = 0.05

if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the groups.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the groups.")
# Out:
# F-statistic: 18.4932
# P-value: 0.0002
# Reject the null hypothesis: There is a significant difference between the groups.

# %%
#ques 18  Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

group1 = [90, 85, 88, 92, 87]
group2 = [78, 80, 84, 76, 79]
group3 = [85, 89, 87, 90, 91]
f_statistic, p_value = stats.f_oneway(group1, group2, group3)

# Print the results
print(f"F-statistic: {f_statistic:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation of the results
alpha = 0.05  # significance level

if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the groups.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the groups.")

# Plot the data
# Combine all groups into a single list and their group labels
data = [group1, group2, group3]
labels = ['Group 1', 'Group 2', 'Group 3']

# Create a boxplot to visualize the distribution of the groups
plt.figure(figsize=(8, 6))
all_data = group1+group2+group3
group_labels = ['group1']*len(group1) + ['group2']*len(group2) + ['group3']*len(group3)
sns.boxplot(x=group_labels,y= all_data, notch=True, patch_artist=True,
            boxprops=dict(facecolor='skyblue', color='black'),
            whiskerprops=dict(color='black', linewidth=1.5),
            flierprops=dict(marker='o', color='red', markersize=8))

# Add titles and labels
plt.title('Boxplot of Test Scores by Group')
plt.xlabel('Group')
plt.ylabel('Test Score')

# Show the plot
plt.show()
# Out:
# F-statistic: 18.4932
# P-value: 0.0002
# Reject the null hypothesis: There is a significant difference between the groups.
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:700: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   artists = ax.bxp(**boxplot_kws)

# %%
#ques 19 Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA.

def check_anova_assumptions(groups):
    """
    This function checks the assumptions of normality, independence, and equal variance for ANOVA.

    Parameters:
    groups (list of lists): A list containing multiple groups of data.
    """
    print("\nChecking Normality:")
    for i, group in enumerate(groups):
        stat, p_value = stats.shapiro(group)
        print(f"Group {i + 1} - Shapiro-Wilk test p-value: {p_value:.4f}")
        if p_value < 0.05:
            print(f"Group {i + 1}: Data does not follow a normal distribution (Reject H0).")
        else:
            print(f"Group {i + 1}: Data follows a normal distribution (Fail to reject H0).")
    plt.figure(figsize=(10, 6))
    for i, group in enumerate(groups):
        plt.subplot(1, len(groups), i + 1)
        stats.probplot(group, dist="norm", plot=plt)
        plt.title(f"Group {i + 1} Q-Q plot")
    plt.tight_layout()
    plt.show()
    print("\nChecking for Equal Variance:")
    stat, p_value = stats.levene(*groups)
    print(f"Levene's test p-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject H0: Variances are not equal (the assumption of homogeneity of variance is violated).")
    else:
        print("Fail to reject H0: Variances are equal (the assumption of homogeneity of variance is met).")
    print("\nAssumption of Independence:")
    print("Independence is assumed based on the design of the study or the data collection process.")
group1 = [90, 85, 88, 92, 87]
group2 = [78, 80, 84, 76, 79]
group3 = [85, 89, 87, 90, 91]
check_anova_assumptions([group1, group2, group3])
# Out:
# Checking Normality:
# Group 1 - Shapiro-Wilk test p-value: 0.9796
# Group 1: Data follows a normal distribution (Fail to reject H0).
# Group 2 - Shapiro-Wilk test p-value: 0.7773
# Group 2: Data follows a normal distribution (Fail to reject H0).
# Group 3 - Shapiro-Wilk test p-value: 0.7869
# Group 3: Data follows a normal distribution (Fail to reject H0).
# Checking for Equal Variance:
# Levene's test p-value: 0.9773
# Fail to reject H0: Variances are equal (the assumption of homogeneity of variance is met).
#
# Assumption of Independence:
# Independence is assumed based on the design of the study or the data collection process.

# %%
#ques 20  Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results

import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
np.random.seed(42)

diet_type = ['Vegetarian', 'Non-Vegetarian']
exercise_level = ['Low', 'Medium', 'High']
data = []
for diet in diet_type:
    for exercise in exercise_level:
        weight_loss = np.random.normal(loc=10, scale=2, size=10) + (exercise == 'High') * 2 + (diet == 'Non-Vegetarian') * 1
        for wl in weight_loss:
            data.append([diet, exercise, wl])
df = pd.DataFrame(data, columns=['Diet', 'Exercise', 'Weight_Loss'])
model = ols('Weight_Loss ~ Diet * Exercise', data=df).fit()  # Diet * Exercise indicates interaction term
anova_table = anova_lm(model, typ=2)
print(anova_table)
if anova_table['PR(>F)'][0] < 0.05:
    print("The main effect of Diet is significant.")
else:
    print("The main effect of Diet is not significant.")

if anova_table['PR(>F)'][1] < 0.05:
    print("The main effect of Exercise is significant.")
else:
    print("The main effect of Exercise is not significant.")

if anova_table['PR(>F)'][2] < 0.05:
    print("There is a significant interaction between Diet and Exercise.")
else:
    print("There is no significant interaction between Diet and Exercise.")
plt.figure(figsize=(8, 6))
sns.pointplot(x='Exercise', y='Weight_Loss', hue='Diet', data=df, dodge=True, markers=["o", "s"], linestyles=["-", "--"])
plt.title('Interaction between Diet Type and Exercise Level on Weight Loss')
plt.xlabel('Exercise Level')
plt.ylabel('Weight Loss (kg)')
plt.legend(title='Diet Type')
plt.show()
# Out:
#                    sum_sq    df          F    PR(>F)
# Diet            19.288280   1.0   6.611521  0.012919
# Exercise        92.713268   2.0  15.889848  0.000004
# Diet:Exercise   20.562126   2.0   3.524081  0.036431
# Residual       157.538211  54.0        NaN       NaN
# The main effect of Diet is significant.
# The main effect of Exercise is significant.
# There is a significant interaction between Diet and Exercise.
# <ipython-input-34-fbc2e1e211ca>:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if anova_table['PR(>F)'][0] < 0.05:
# ...

# %%
#ques 21 Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing.
def plot_f_distribution(df1_values, df2_values):
    x = np.linspace(0, 5, 1000)

    plt.figure(figsize=(10, 6))
    for df1 in df1_values:
        for df2 in df2_values:
            y = stats.f.pdf(x, df1, df2)
    plt.title('F-Distribution for Different Degrees of Freedom')
    plt.xlabel('F-statistic (F)')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()
df1_values = [1, 2, 5]
df2_values = [10, 20, 30]
plot_f_distribution(df1_values, df2_values)
# Out:
# <ipython-input-41-81973583e7e1>:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#ques 22  Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means.

group1 = [90, 85, 88, 92, 87]
group2 = [78, 80, 84, 76, 79]
group3 = [85, 89, 87, 90, 91]
f_statistic, p_value = stats.f_oneway(group1, group2, group3)
print(f"F-statistic: {f_statistic:.4f}")
print(f"P-value: {p_value:.4f}")
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the groups.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the groups.")
data = [group1, group2, group3]
labels = ['Group 1', 'Group 2', 'Group 3']
plt.figure(figsize=(8, 6))
group_labels = [label for label, group_data in zip(labels, data) for _ in group_data]
all_data = [data_point for group_data in data for data_point in group_data]
sns.boxplot(x=group_labels, y=all_data,  notch=True, patch_artist=True,
            boxprops=dict(facecolor='skyblue', color='black'),
            whiskerprops=dict(color='black', linewidth=1.5),
            flierprops=dict(marker='o', color='red', markersize=8))
plt.title('Boxplot of Test Scores by Teaching Method')
plt.xlabel('Teaching Method')
plt.ylabel('Test Score')
plt.show()
# Out:
# F-statistic: 18.4932
# P-value: 0.0002
# Reject the null hypothesis: There is a significant difference between the groups.
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:700: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   artists = ax.bxp(**boxplot_kws)

# %%
#ques 23  Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means.

np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)
group2 = np.random.normal(loc=55, scale=10, size=30)
t_statistic, p_value = stats.ttest_ind(group1, group2)
print(f"T-statistic: {t_statistic:.4f}")
print(f"P-value: {p_value:.4f}")
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the means of the two groups.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the means of the two groups.")
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.boxplot([group1, group2], labels=['Group 1', 'Group 2'], notch=True, patch_artist=True,
            boxprops=dict(facecolor='skyblue', color='black'),
            whiskerprops=dict(color='black', linewidth=1.5),
            flierprops=dict(marker='o', color='red', markersize=8))
plt.title('Boxplot: Group 1 vs Group 2')
plt.ylabel('Values')
plt.subplot(1, 2, 2)
plt.hist(group1, bins=15, alpha=0.7, label='Group 1', color='skyblue', edgecolor='black')
plt.hist(group2, bins=15, alpha=0.7, label='Group 2', color='orange', edgecolor='black')
plt.title('Histogram: Group 1 vs Group 2')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# T-statistic: -2.3981
# P-value: 0.0197
# Reject the null hypothesis: There is a significant difference between the means of the two groups.
# <ipython-input-44-59a731150a19>:16: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1, group2], labels=['Group 1', 'Group 2'], notch=True, patch_artist=True,

# %%
#ques 24  Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results.

np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=10, size=30)
sigma_0_squared = 100
n = len(sample_data)
sample_variance = np.var(sample_data, ddof=1)
chi_square_statistic = (n - 1) * sample_variance / sigma_0_squared
df = n - 1
p_value = 2 * min(stats.chi2.cdf(chi_square_statistic, df), 1 - stats.chi2.cdf(chi_square_statistic, df))
alpha = 0.05
print(f"Chi-square Statistic: {chi_square_statistic:.4f}")
print(f"P-value: {p_value:.4f}")
if p_value < alpha:
    print("Reject the null hypothesis: The population variance is significantly different from 100.")
else:
    print("Fail to reject the null hypothesis: The population variance is not significantly different from 100.")
# Out:
# Chi-square Statistic: 23.4903
# P-value: 0.4927
# Fail to reject the null hypothesis: The population variance is not significantly different from 100.

# %%
#ques 25 Write a Python script to perform a Z-test for comparing proportions between two datasets or groups.

x1 = 120
n1 = 200
x2 = 110
n2 = 180
p1 = x1 / n1
p2 = x2 / n2
P = (x1 + x2) / (n1 + n2)
z_statistic = (p1 - p2) / np.sqrt(P * (1 - P) * (1/n1 + 1/n2))
p_value = 2 * (1 - stats.norm.cdf(np.abs(z_statistic)))
alpha = 0.05
print(f"Z-statistic: {z_statistic:.4f}")
print(f"P-value: {p_value:.4f}")
if p_value < alpha:
    print("Reject the null hypothesis: The proportions are significantly different.")
else:
    print("Fail to reject the null hypothesis: The proportions are not significantly different.")
# Out:
# Z-statistic: -0.2213
# P-value: 0.8249
# Fail to reject the null hypothesis: The proportions are not significantly different.

# %%
#ques 26  Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results.

np.random.seed(42)
data1 = np.random.normal(loc=50, scale=10, size=30)
data2 = np.random.normal(loc=50, scale=20, size=30)
var1 = np.var(data1, ddof=1)
var2 = np.var(data2, ddof=1)
if var1 > var2:
    F_statistic = var1 / var2
    df1 = len(data1) - 1
    df2 = len(data2) - 1
else:
    F_statistic = var2 / var1
    df1 = len(data2) - 1
    df2 = len(data1) - 1
p_value = 1 - stats.f.cdf(F_statistic, df1, df2)
alpha = 0.05
print(f"F-statistic: {F_statistic:.4f}")
print(f"P-value: {p_value:.4f}")
if p_value < alpha:
    print("Reject the null hypothesis: The variances are significantly different.")
else:
    print("Fail to reject the null hypothesis: The variances are not significantly different.")
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.boxplot([data1, data2], labels=['Dataset 1', 'Dataset 2'], notch=True, patch_artist=True,
            boxprops=dict(facecolor='lightblue', color='black'),
            whiskerprops=dict(color='black', linewidth=1.5),
            flierprops=dict(marker='o', color='red', markersize=8))
plt.title('Boxplot: Dataset 1 vs Dataset 2')
plt.ylabel('Values')
x = np.linspace(0, 5, 500)
y = stats.f.pdf(x, df1, df2)

plt.subplot(1, 2, 2)
plt.plot(x, y, 'b-', label=f'F-distribution df1={df1}, df2={df2}')
plt.axvline(x=F_statistic, color='red', linestyle='--', label=f'F-statistic = {F_statistic:.4f}')
plt.title('F-distribution and F-statistic')
plt.xlabel('F')
plt.ylabel('Density')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# F-statistic: 4.2812
# P-value: 0.0001
# Reject the null hypothesis: The variances are significantly different.
# <ipython-input-48-3e21e7e11ba4>:26: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data1, data2], labels=['Dataset 1', 'Dataset 2'], notch=True, patch_artist=True,

# %%
#ques 27  Perform a Chi-square test for goodness of fit with simulated data and analyze the results.

np.random.seed(42)
observed_data = np.random.choice([1, 2, 3, 4, 5, 6], size=120)
observed_freq = [np.sum(observed_data == i) for i in range(1, 7)]
expected_freq = [120 / 6] * 6
chi_square_statistic, p_value = stats.chisquare(observed_freq, expected_freq)
print(f"Chi-square Statistic: {chi_square_statistic:.4f}")
print(f"P-value: {p_value:.4f}")
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The data does not fit the expected distribution.")
else:
    print("Fail to reject the null hypothesis: The data fits the expected distribution.")
x = np.arange(1, 7)

plt.figure(figsize=(10, 6))
plt.bar(x - 0.2, observed_freq, width=0.4, label="Observed Frequencies", color='lightblue', align='center')
plt.bar(x + 0.2, expected_freq, width=0.4, label="Expected Frequencies", color='orange', align='center')
plt.xlabel("Die Face")
plt.ylabel("Frequency")
plt.title("Chi-square Goodness of Fit Test: Die Rolls")
plt.legend()
plt.xticks(x)
plt.show()
# Out:
# Chi-square Statistic: 4.6000
# P-value: 0.4666
# Fail to reject the null hypothesis: The data fits the expected distribution.
